# %%
import requests
from bs4 import BeautifulSoup
import time

def get_html_links(url):
    links_list = []

    response = requests.get(url, headers=headers)
    response.encoding = 'gbk'

    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find('div', class_='article-chapter-list').find_all('a')

    for link in links:
        href = url + link.get('href')
        title = link.text

        links_list.append({'title': title, 'href': href})

    return links_list



url = 'https://www.m298.com/798comic_269544/'

headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }

page_links = get_html_links(url)

for page_link in page_links:
    title = page_link['title']
    url = page_link['href']

    print(title)
    print(url)
    response = requests.get(url, headers=headers)
    response.encoding = 'gbk'
    print(response.text)

    time.sleep(1)
# Out:
# 第01话
# https://www.m298.com/798comic_269544/789750.html
# <!doctype html>
# <html>
# 	<head>
# 		<meta charset="gbk" />
# 		<title>无职转生洛琪希也要拿出真本事漫画“第01话”在线免费观看下拉式阅读，漫迷二九八</title>
# 		<meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 		<meta name="keywords" content="无职转生洛琪希也要拿出真本事漫画,无职转生洛琪希也要拿出真本事漫画在线,无职转生洛琪希也要拿出真本事漫画免费,无职转生洛琪希也要拿出真本事漫画免费阅读,无职转生洛琪希也要拿出真本事漫画在线观看,无职转生洛琪希也要拿出真本事漫画下拉式" />
# 		<meta name="description" content="无职转生洛琪希也要拿出真本事漫画“第01话”在线免费观看下拉式阅读，漫画剧情：描述小说无职转生到了异世界就拿出真本事中人气角色洛琪希的人生的外传漫画。 发觉自己从出生时就没有一族" />
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 		<link rel="shortcut icon" type="image/x-icon" href="https://www.m298.com/favicon.ico" media="screen" />
# 		<!-- <link href="/static/css/style.css" type="text/css" rel="stylesheet"> -->
#
# 		<link href="/static/css/base.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link href="/static/css/main.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link rel="stylesheet" href="/static/font/iconfont.css">
#
# 		<!-- <link rel="stylesheet" href="/static/css/font-awesome.min.css"> -->
# 		<!--[if IE 7]><link rel="stylesheet" href="//cdn.bootcss.com/font-awesome/3.2.1/css/font-awesome-ie7.min.css"><![endif]-->
# 		<script type="text/javascript" src="https://apps.bdimg.com/libs/jquery/1.7.2/jquery.min.js"></script>
# 		<script type="text/javascript" src="/static/js/common.js?v=1.0.5"></script>
# 		<!-- <script type="text/javascript" src="/static/js/jquery.lazyload.js"></script> -->
# 		<script type="text/javascript" src="/static/js/yuedu.js?v=1.0.5"></script>
# 	</head>
# 	<body class="chapter-page">
# 		<div class="chapter-header">
# 			<div class="header-logo"><a href="/"><img src="/static/images/logo.png" alt="logo"></a></div>
# 			<div class="header-full"><a id="js_full_screen" href="javascript:void(0);">全屏</a></div>
# 			<div class="header-center line-clamp-1">
# 				<a href="/">首页</a> > <a href="/798comic_269544/">无职转生洛琪希也要拿出真本事</a> > <span>第01话</span>
# 			</div>
# 		</div>
# 		<div class="chapter-tool-box">
# 			<!-- <div class="tool-item">
# 				<span class="iconfont icon-shoucang_2"></span>
# 				<span>收藏</span>
# 			</div> -->
# 			<div class="tool-item" id="open_lights">
# 				<span class="iconfont icon-kaideng"></span>
# 				<span>关灯</span>
# 			</div>
# 			<div class="tool-item" id="open_chapter">
# 				<span class="iconfont icon-mulu"></span>
# 				<span>章节</span>
# 			</div>
# 			<div class="tool-tag"></div>
#
# 			<a href="https://www.m298.com/798comic_269544/" class="tool-item">
#
# 				<span class="iconfont icon-shangyihua"></span>
# 				<span>上一话</span>
# 			</a>
#
# 			<a href="https://www.m298.com/798comic_269544/789751.html" class="tool-item">
#
# 				<span class="iconfont icon-xiayihua"></span>
# 				<span>下一话</span>
# 			</a>
# 		</div>
# 		<div class="arrow-ri none">
# 			<div class="arrow-ri-s"></div>
# 		</div>
# 		<div class="chapter-list none">
# 			<h2 class="line-clamp-1">《无职转生洛琪希也要拿出真本事》目录</h2>
# 			<div class="chapter-list-scroll">
# 				<ul id="789750">
#
# 				</ul>
# 			</div>
# 		</div>
# 		<div class="article-content-box container clearfix mt20">
# 			<div class="chapter-content" >
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/1_3698dc.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/2_6e8cac.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/3_bb4543.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/4_e7c484.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/5_ab1951.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/6_c3f293.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/7_fcd091.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/8_455aae.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/9_b6db60.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/10_ab636a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/11_fd8f21.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/12_5e0672.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/13_0ce8fb.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/14_2fa85a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/15_ba503b.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/16_10761b.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/17_d8a046.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/18_f69ede.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/19_79a0ae.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/20_fa9970.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/21_eb042e.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/22_373d56.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/23_ab036e.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/24_905886.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/25_79c8b2.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/26_290ab3.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/27_2fa250.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/28_3944a8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/29_0e0da8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/30_a9ea87.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/31_98e1de.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/32_03527c.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/33_58228f.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731605/34_db7181.jpg" alt="" style="display: inline-block;">
#
# 			</div>
# 			<div class="class-block-box clearfix" style="float:left;width:100%;">
# 				<div class="class-head" >
# 					<span>精品</span><span class="select-color">推荐</span>
# 				</div>
# 				<ul class="cartoon-block-box clearfix" >
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_289447/">
# 								<img src="https://img.testrainshine.top/prod/72/72735/72735s.jpg" alt="网球王子"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第379话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_289447/" class="hover-a">网球王子</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287906/">
# 								<img src="https://img.testrainshine.top/prod/71/71171/71171s.jpg" alt="神厨狂后"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第295话 别挣扎了</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287906/" class="hover-a">神厨狂后</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_296886/">
# 								<img src="https://img.testrainshine.top/" alt="黑礁"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第116话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_296886/" class="hover-a">黑礁</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287530/">
# 								<img src="https://img.testrainshine.top/prod/70/70794/70794s.jpg" alt="灵契"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">十周年读者同人作品展</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287530/" class="hover-a">灵契</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_220976/">
# 								<img src="https://img.testrainshine.top/prod/2/2110/2110s.jpg" alt="偷偷爱着你"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">动画化决定海报</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_220976/" class="hover-a">偷偷爱着你</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_298195/">
# 								<img src="https://img.testrainshine.top/prod/81/81513/81513s.jpg" alt="电影少女"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">爱藏版09卷</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_298195/" class="hover-a">电影少女</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_289156/">
# 								<img src="https://img.testrainshine.top/prod/72/72444/72444s.jpg" alt="浪漫传说"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">创世神的不幸日！新郎不是你！</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_289156/" class="hover-a">浪漫传说</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 				</ul>
# 			</div>
# 		</div>
# 		<script>
# 			$(function(){
# 				openTopBarId = false;
# 				// 开灯的设置
# 				open_lights = 0;
# 				kaideng();
# 				// 设置顶部状态栏的显隐
# 				showHideTop();
# 				// $(".lazy-img").lazyload();
# 				setChapterList();
# 				$('#js_full_screen').click(function(de){
# 					changeFullScreen();
# 				})
# 			});
# 			// 获取章节列表
# 			chapterPageGetList('269544');
# 			// 记录阅读记录
#             history_save({
# 				articleid:'269544',
# 				articlename:'无职转生洛琪希也要拿出真本事',
# 				articlelink:'/798comic_269544/',
# 				cover_image:'https://img.testrainshine.top/prod/52/52134/52134s.jpg',
# 				chapterlink_read:'/798comic_269544/789750.html',
# 				chapterid_read:'789750',
# 				chaptername_read:'第01话',
# 				author:'石见翔子'});
# 			function setChapterList(){
# 				$('body').click(function(){
# 					$('.chapter-list').addClass('none');
# 					$('.arrow-ri').addClass('none');
# 					if(!openTopBarId){
# 						$('.chapter-header').stop().css('top','0px');
# 						openTopBarId = true;
# 					}else{
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					}
# 				})
# 				$('.chapter-list').click(function(e){
# 					e.stopPropagation();
# 				})
# 				$('#open_chapter').click(function(e){
# 					e.stopPropagation();
# 					if($('.chapter-list').attr('class').indexOf('none')>=0){
# 						// 展示章节
# 						$('.chapter-list').removeClass('none');
# 						$('.arrow-ri').removeClass('none');
# 					}else{
# 						$('.chapter-list').addClass('none');
# 						$('.arrow-ri').addClass('none');
# 					}
# 				})
# 			}
# 			// 设置开关灯
# 			function kaideng(){
# 				$('#open_lights').click(function(e){
# 					e.stopPropagation();
# 					if(tool_kaideng == 1){
# 						Cookie.set("tool_kaideng",0);
# 						tool_kaideng = 0;
# 						$('.chapter-page').removeClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('关灯');
# 					}else{
# 						Cookie.set("tool_kaideng",1);
# 						tool_kaideng = 1;
# 						$('.chapter-page').addClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('开灯');
# 					}
# 				});
# 				tool_kaideng = Cookie.get("tool_kaideng")?Cookie.get("tool_kaideng"):0;
# 				if(tool_kaideng == 1){
# 					// 关灯
# 					$('.chapter-page').addClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('开灯');
# 				}else{
# 					// 默认开灯
# 					$('.chapter-page').removeClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('关灯');
# 				}
# 			}
# 			// 设置顶部状态栏的显隐
# 			function showHideTop(){
# 				var position = $(window).scrollTop();
# 				$(window).scroll(function(event){
# 					var scroll = $(window).scrollTop();
# 					if(scroll > position+30) {
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					} else {
# 						// 向下滑动内容
# 						if((scroll < position-30) && openTopBarId == false) {
# 							openTopBarId = true;
# 							$('.chapter-header').stop().css('top','0px');
# 						}
# 					}
# 					position = scroll;
# 				});
# 			}
# 			// 全屏
# 			function changeFullScreen() {
#         		document.fullscreenElement || document.mozFullScreenElement || document.webkitFullscreenElement || document.msFullscreenElement ? document.exitFullscreen ? document.exitFullscreen() : document.msExitFullscreen ? document.msExitFullscreen() : document.mozCancelFullScreen ? document.mozCancelFullScreen() : document.webkitExitFullscreen && document.webkitExitFullscreen() : document.documentElement.requestFullscreen ? document.documentElement.requestFullscreen() : document.documentElement.msRequestFullscreen ? document.documentElement.msRequestFullscreen() : document.documentElement.mozRequestFullScreen ? document.documentElement.mozRequestFullScreen() : document.documentElement.webkitRequestFullscreen && document.documentElement.webkitRequestFullscreen(Element.ALLOW_KEYBOARD_INPUT)
# 			}
# 			platform();
# 		</script>
# 	</body>
# </html>
# 第02话
# https://www.m298.com/798comic_269544/789751.html
# <!doctype html>
# <html>
# 	<head>
# 		<meta charset="gbk" />
# 		<title>无职转生洛琪希也要拿出真本事漫画“第02话”在线免费观看下拉式阅读，漫迷二九八</title>
# 		<meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 		<meta name="keywords" content="无职转生洛琪希也要拿出真本事漫画,无职转生洛琪希也要拿出真本事漫画在线,无职转生洛琪希也要拿出真本事漫画免费,无职转生洛琪希也要拿出真本事漫画免费阅读,无职转生洛琪希也要拿出真本事漫画在线观看,无职转生洛琪希也要拿出真本事漫画下拉式" />
# 		<meta name="description" content="无职转生洛琪希也要拿出真本事漫画“第02话”在线免费观看下拉式阅读，漫画剧情：描述小说无职转生到了异世界就拿出真本事中人气角色洛琪希的人生的外传漫画。 发觉自己从出生时就没有一族" />
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 		<link rel="shortcut icon" type="image/x-icon" href="https://www.m298.com/favicon.ico" media="screen" />
# 		<!-- <link href="/static/css/style.css" type="text/css" rel="stylesheet"> -->
#
# 		<link href="/static/css/base.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link href="/static/css/main.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link rel="stylesheet" href="/static/font/iconfont.css">
#
# 		<!-- <link rel="stylesheet" href="/static/css/font-awesome.min.css"> -->
# 		<!--[if IE 7]><link rel="stylesheet" href="//cdn.bootcss.com/font-awesome/3.2.1/css/font-awesome-ie7.min.css"><![endif]-->
# 		<script type="text/javascript" src="https://apps.bdimg.com/libs/jquery/1.7.2/jquery.min.js"></script>
# 		<script type="text/javascript" src="/static/js/common.js?v=1.0.5"></script>
# 		<!-- <script type="text/javascript" src="/static/js/jquery.lazyload.js"></script> -->
# 		<script type="text/javascript" src="/static/js/yuedu.js?v=1.0.5"></script>
# 	</head>
# 	<body class="chapter-page">
# 		<div class="chapter-header">
# 			<div class="header-logo"><a href="/"><img src="/static/images/logo.png" alt="logo"></a></div>
# 			<div class="header-full"><a id="js_full_screen" href="javascript:void(0);">全屏</a></div>
# 			<div class="header-center line-clamp-1">
# 				<a href="/">首页</a> > <a href="/798comic_269544/">无职转生洛琪希也要拿出真本事</a> > <span>第02话</span>
# 			</div>
# 		</div>
# 		<div class="chapter-tool-box">
# 			<!-- <div class="tool-item">
# 				<span class="iconfont icon-shoucang_2"></span>
# 				<span>收藏</span>
# 			</div> -->
# 			<div class="tool-item" id="open_lights">
# 				<span class="iconfont icon-kaideng"></span>
# 				<span>关灯</span>
# 			</div>
# 			<div class="tool-item" id="open_chapter">
# 				<span class="iconfont icon-mulu"></span>
# 				<span>章节</span>
# 			</div>
# 			<div class="tool-tag"></div>
#
# 			<a  href="https://www.m298.com/798comic_269544/789750.html" class="tool-item">
#
# 				<span class="iconfont icon-shangyihua"></span>
# 				<span>上一话</span>
# 			</a>
#
# 			<a href="https://www.m298.com/798comic_269544/789748.html" class="tool-item">
#
# 				<span class="iconfont icon-xiayihua"></span>
# 				<span>下一话</span>
# 			</a>
# 		</div>
# 		<div class="arrow-ri none">
# 			<div class="arrow-ri-s"></div>
# 		</div>
# 		<div class="chapter-list none">
# 			<h2 class="line-clamp-1">《无职转生洛琪希也要拿出真本事》目录</h2>
# 			<div class="chapter-list-scroll">
# 				<ul id="789751">
#
# 				</ul>
# 			</div>
# 		</div>
# 		<div class="article-content-box container clearfix mt20">
# 			<div class="chapter-content" >
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/1_f061a3.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/2_b60b94.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/3_f6f353.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/4_4e019a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/5_5d3359.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/6_298d06.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/7_ebdeff.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/8_717f07.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/9_10bad5.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/10_73a562.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/11_332922.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/12_9e8d93.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/13_ed8eb8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/14_623188.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/15_f9485a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/16_a7efb0.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/17_2b520a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/18_8454ec.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/19_25a365.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/20_85188c.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/21_0ca9e1.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/22_d275ea.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/23_0d942f.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/24_36de9f.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/25_b83ef7.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/26_9f053c.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/27_f2a311.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/28_61df7a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/29_a95860.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/30_e82150.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/31_7ecc3a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/32_3e5437.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/33_55760c.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/34_a86fc7.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731604/35_6f73a7.jpg" alt="" style="display: inline-block;">
#
# 			</div>
# 			<div class="class-block-box clearfix" style="float:left;width:100%;">
# 				<div class="class-head" >
# 					<span>精品</span><span class="select-color">推荐</span>
# 				</div>
# 				<ul class="cartoon-block-box clearfix" >
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287976/">
# 								<img src="https://img.testrainshine.top/prod/71/71241/71241s.jpg" alt="尸兄（我叫白小飞）"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">2025新年快乐</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287976/" class="hover-a">尸兄（我叫白小飞）</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_291625/">
# 								<img src="https://img.testrainshine.top/prod/74/74913/74913s.jpg" alt="无限恐怖"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第71话3 强化闪灵</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_291625/" class="hover-a">无限恐怖</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287798/">
# 								<img src="https://img.testrainshine.top/prod/71/71063/71063s.jpg" alt="斗罗大陆 第三部 龙王传说"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">381 五十一号男生揭面</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287798/" class="hover-a">斗罗大陆 第三部 龙王传说</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_220907/">
# 								<img src="https://img.testrainshine.top/prod/2/2040/2040s.jpg" alt="我能看到成功率"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第346话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_220907/" class="hover-a">我能看到成功率</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287712/">
# 								<img src="https://img.testrainshine.top/prod/70/70977/70977s.jpg" alt="排球少年！！"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">特别短篇 祭典再临</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287712/" class="hover-a">排球少年！！</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_218993/">
# 								<img src="https://img.testrainshine.top/prod/0/124/124s.jpg" alt="神精榜"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">最终话 大结局·尾声2</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_218993/" class="hover-a">神精榜</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_221630/">
# 								<img src="https://img.testrainshine.top/prod/2/2777/2777s.jpg" alt="我们的存在"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第70话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_221630/" class="hover-a">我们的存在</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 				</ul>
# 			</div>
# 		</div>
# 		<script>
# 			$(function(){
# 				openTopBarId = false;
# 				// 开灯的设置
# 				open_lights = 0;
# 				kaideng();
# 				// 设置顶部状态栏的显隐
# 				showHideTop();
# 				// $(".lazy-img").lazyload();
# 				setChapterList();
# 				$('#js_full_screen').click(function(de){
# 					changeFullScreen();
# 				})
# 			});
# 			// 获取章节列表
# 			chapterPageGetList('269544');
# 			// 记录阅读记录
#             history_save({
# 				articleid:'269544',
# 				articlename:'无职转生洛琪希也要拿出真本事',
# 				articlelink:'/798comic_269544/',
# 				cover_image:'https://img.testrainshine.top/prod/52/52134/52134s.jpg',
# 				chapterlink_read:'/798comic_269544/789751.html',
# 				chapterid_read:'789751',
# 				chaptername_read:'第02话',
# 				author:'石见翔子'});
# 			function setChapterList(){
# 				$('body').click(function(){
# 					$('.chapter-list').addClass('none');
# 					$('.arrow-ri').addClass('none');
# 					if(!openTopBarId){
# 						$('.chapter-header').stop().css('top','0px');
# 						openTopBarId = true;
# 					}else{
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					}
# 				})
# 				$('.chapter-list').click(function(e){
# 					e.stopPropagation();
# 				})
# 				$('#open_chapter').click(function(e){
# 					e.stopPropagation();
# 					if($('.chapter-list').attr('class').indexOf('none')>=0){
# 						// 展示章节
# 						$('.chapter-list').removeClass('none');
# 						$('.arrow-ri').removeClass('none');
# 					}else{
# 						$('.chapter-list').addClass('none');
# 						$('.arrow-ri').addClass('none');
# 					}
# 				})
# 			}
# 			// 设置开关灯
# 			function kaideng(){
# 				$('#open_lights').click(function(e){
# 					e.stopPropagation();
# 					if(tool_kaideng == 1){
# 						Cookie.set("tool_kaideng",0);
# 						tool_kaideng = 0;
# 						$('.chapter-page').removeClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('关灯');
# 					}else{
# 						Cookie.set("tool_kaideng",1);
# 						tool_kaideng = 1;
# 						$('.chapter-page').addClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('开灯');
# 					}
# 				});
# 				tool_kaideng = Cookie.get("tool_kaideng")?Cookie.get("tool_kaideng"):0;
# 				if(tool_kaideng == 1){
# 					// 关灯
# 					$('.chapter-page').addClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('开灯');
# 				}else{
# 					// 默认开灯
# 					$('.chapter-page').removeClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('关灯');
# 				}
# 			}
# 			// 设置顶部状态栏的显隐
# 			function showHideTop(){
# 				var position = $(window).scrollTop();
# 				$(window).scroll(function(event){
# 					var scroll = $(window).scrollTop();
# 					if(scroll > position+30) {
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					} else {
# 						// 向下滑动内容
# 						if((scroll < position-30) && openTopBarId == false) {
# 							openTopBarId = true;
# 							$('.chapter-header').stop().css('top','0px');
# 						}
# 					}
# 					position = scroll;
# 				});
# 			}
# 			// 全屏
# 			function changeFullScreen() {
#         		document.fullscreenElement || document.mozFullScreenElement || document.webkitFullscreenElement || document.msFullscreenElement ? document.exitFullscreen ? document.exitFullscreen() : document.msExitFullscreen ? document.msExitFullscreen() : document.mozCancelFullScreen ? document.mozCancelFullScreen() : document.webkitExitFullscreen && document.webkitExitFullscreen() : document.documentElement.requestFullscreen ? document.documentElement.requestFullscreen() : document.documentElement.msRequestFullscreen ? document.documentElement.msRequestFullscreen() : document.documentElement.mozRequestFullScreen ? document.documentElement.mozRequestFullScreen() : document.documentElement.webkitRequestFullscreen && document.documentElement.webkitRequestFullscreen(Element.ALLOW_KEYBOARD_INPUT)
# 			}
# 			platform();
# 		</script>
# 	</body>
# </html>
# 第03话
# https://www.m298.com/798comic_269544/789748.html
# <!doctype html>
# <html>
# 	<head>
# 		<meta charset="gbk" />
# 		<title>无职转生洛琪希也要拿出真本事漫画“第03话”在线免费观看下拉式阅读，漫迷二九八</title>
# 		<meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 		<meta name="keywords" content="无职转生洛琪希也要拿出真本事漫画,无职转生洛琪希也要拿出真本事漫画在线,无职转生洛琪希也要拿出真本事漫画免费,无职转生洛琪希也要拿出真本事漫画免费阅读,无职转生洛琪希也要拿出真本事漫画在线观看,无职转生洛琪希也要拿出真本事漫画下拉式" />
# 		<meta name="description" content="无职转生洛琪希也要拿出真本事漫画“第03话”在线免费观看下拉式阅读，漫画剧情：描述小说无职转生到了异世界就拿出真本事中人气角色洛琪希的人生的外传漫画。 发觉自己从出生时就没有一族" />
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 		<link rel="shortcut icon" type="image/x-icon" href="https://www.m298.com/favicon.ico" media="screen" />
# 		<!-- <link href="/static/css/style.css" type="text/css" rel="stylesheet"> -->
#
# 		<link href="/static/css/base.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link href="/static/css/main.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link rel="stylesheet" href="/static/font/iconfont.css">
#
# 		<!-- <link rel="stylesheet" href="/static/css/font-awesome.min.css"> -->
# 		<!--[if IE 7]><link rel="stylesheet" href="//cdn.bootcss.com/font-awesome/3.2.1/css/font-awesome-ie7.min.css"><![endif]-->
# 		<script type="text/javascript" src="https://apps.bdimg.com/libs/jquery/1.7.2/jquery.min.js"></script>
# 		<script type="text/javascript" src="/static/js/common.js?v=1.0.5"></script>
# 		<!-- <script type="text/javascript" src="/static/js/jquery.lazyload.js"></script> -->
# 		<script type="text/javascript" src="/static/js/yuedu.js?v=1.0.5"></script>
# 	</head>
# 	<body class="chapter-page">
# 		<div class="chapter-header">
# 			<div class="header-logo"><a href="/"><img src="/static/images/logo.png" alt="logo"></a></div>
# 			<div class="header-full"><a id="js_full_screen" href="javascript:void(0);">全屏</a></div>
# 			<div class="header-center line-clamp-1">
# 				<a href="/">首页</a> > <a href="/798comic_269544/">无职转生洛琪希也要拿出真本事</a> > <span>第03话</span>
# 			</div>
# 		</div>
# 		<div class="chapter-tool-box">
# 			<!-- <div class="tool-item">
# 				<span class="iconfont icon-shoucang_2"></span>
# 				<span>收藏</span>
# 			</div> -->
# 			<div class="tool-item" id="open_lights">
# 				<span class="iconfont icon-kaideng"></span>
# 				<span>关灯</span>
# 			</div>
# 			<div class="tool-item" id="open_chapter">
# 				<span class="iconfont icon-mulu"></span>
# 				<span>章节</span>
# 			</div>
# 			<div class="tool-tag"></div>
#
# 			<a  href="https://www.m298.com/798comic_269544/789751.html" class="tool-item">
#
# 				<span class="iconfont icon-shangyihua"></span>
# 				<span>上一话</span>
# 			</a>
#
# 			<a href="https://www.m298.com/798comic_269544/789749.html" class="tool-item">
#
# 				<span class="iconfont icon-xiayihua"></span>
# 				<span>下一话</span>
# 			</a>
# 		</div>
# 		<div class="arrow-ri none">
# 			<div class="arrow-ri-s"></div>
# 		</div>
# 		<div class="chapter-list none">
# 			<h2 class="line-clamp-1">《无职转生洛琪希也要拿出真本事》目录</h2>
# 			<div class="chapter-list-scroll">
# 				<ul id="789748">
#
# 				</ul>
# 			</div>
# 		</div>
# 		<div class="article-content-box container clearfix mt20">
# 			<div class="chapter-content" >
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/1_fbb0c9.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/2_f75ed6.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/3_378036.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/4_14fe06.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/5_00ebce.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/6_412fec.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/7_ba3701.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/8_e71a62.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/9_547ce8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/10_b497fa.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/11_a0ce40.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/12_92d251.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/13_2d7628.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/14_9716d8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/15_d759b6.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/16_c05a7b.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/17_fbe77d.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/18_5d95f4.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/19_a6b7be.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/20_ebca16.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/21_47ef20.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/22_b38a46.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/23_53bd11.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/24_00f371.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/25_1d07b6.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/26_263bbe.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/27_c220b5.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/28_d992d6.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/29_2694a2.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/30_8d429e.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/31_8378f6.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/32_9cc999.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731608/33_7a7e98.jpg" alt="" style="display: inline-block;">
#
# 			</div>
# 			<div class="class-block-box clearfix" style="float:left;width:100%;">
# 				<div class="class-head" >
# 					<span>精品</span><span class="select-color">推荐</span>
# 				</div>
# 				<ul class="cartoon-block-box clearfix" >
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_290398/">
# 								<img src="https://img.testrainshine.top/prod/73/73686/73686s.jpg" alt="黑执事"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第201话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_290398/" class="hover-a">黑执事</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_221269/">
# 								<img src="https://img.testrainshine.top/prod/2/2407/2407s.jpg" alt="公主公主"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">vol_05</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_221269/" class="hover-a">公主公主</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_291164/">
# 								<img src="https://img.testrainshine.top/prod/74/74452/74452s.jpg" alt="格莱普尼尔"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">最终话 后来的世界</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_291164/" class="hover-a">格莱普尼尔</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_224061/">
# 								<img src="https://img.testrainshine.top/prod/5/5242/5242s.jpg" alt="电器街的漫画店"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">番外篇</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_224061/" class="hover-a">电器街的漫画店</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_296696/">
# 								<img src="https://img.testrainshine.top/prod/80/80014/80014s.jpg" alt="朝5晚9"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第85话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_296696/" class="hover-a">朝5晚9</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287566/">
# 								<img src="https://img.testrainshine.top/prod/70/70830/70830s.jpg" alt="重生之都市修仙"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第1046回</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287566/" class="hover-a">重生之都市修仙</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_220758/">
# 								<img src="https://img.testrainshine.top/prod/1/1891/1891s.jpg" alt="朝堂有妖气"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第144话 生生世世不分离</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_220758/" class="hover-a">朝堂有妖气</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 				</ul>
# 			</div>
# 		</div>
# 		<script>
# 			$(function(){
# 				openTopBarId = false;
# 				// 开灯的设置
# 				open_lights = 0;
# 				kaideng();
# 				// 设置顶部状态栏的显隐
# 				showHideTop();
# 				// $(".lazy-img").lazyload();
# 				setChapterList();
# 				$('#js_full_screen').click(function(de){
# 					changeFullScreen();
# 				})
# 			});
# 			// 获取章节列表
# 			chapterPageGetList('269544');
# 			// 记录阅读记录
#             history_save({
# 				articleid:'269544',
# 				articlename:'无职转生洛琪希也要拿出真本事',
# 				articlelink:'/798comic_269544/',
# 				cover_image:'https://img.testrainshine.top/prod/52/52134/52134s.jpg',
# 				chapterlink_read:'/798comic_269544/789748.html',
# 				chapterid_read:'789748',
# 				chaptername_read:'第03话',
# 				author:'石见翔子'});
# 			function setChapterList(){
# 				$('body').click(function(){
# 					$('.chapter-list').addClass('none');
# 					$('.arrow-ri').addClass('none');
# 					if(!openTopBarId){
# 						$('.chapter-header').stop().css('top','0px');
# 						openTopBarId = true;
# 					}else{
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					}
# 				})
# 				$('.chapter-list').click(function(e){
# 					e.stopPropagation();
# 				})
# 				$('#open_chapter').click(function(e){
# 					e.stopPropagation();
# 					if($('.chapter-list').attr('class').indexOf('none')>=0){
# 						// 展示章节
# 						$('.chapter-list').removeClass('none');
# 						$('.arrow-ri').removeClass('none');
# 					}else{
# 						$('.chapter-list').addClass('none');
# 						$('.arrow-ri').addClass('none');
# 					}
# 				})
# 			}
# 			// 设置开关灯
# 			function kaideng(){
# 				$('#open_lights').click(function(e){
# 					e.stopPropagation();
# 					if(tool_kaideng == 1){
# 						Cookie.set("tool_kaideng",0);
# 						tool_kaideng = 0;
# 						$('.chapter-page').removeClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('关灯');
# 					}else{
# 						Cookie.set("tool_kaideng",1);
# 						tool_kaideng = 1;
# 						$('.chapter-page').addClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('开灯');
# 					}
# 				});
# 				tool_kaideng = Cookie.get("tool_kaideng")?Cookie.get("tool_kaideng"):0;
# 				if(tool_kaideng == 1){
# 					// 关灯
# 					$('.chapter-page').addClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('开灯');
# 				}else{
# 					// 默认开灯
# 					$('.chapter-page').removeClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('关灯');
# 				}
# 			}
# 			// 设置顶部状态栏的显隐
# 			function showHideTop(){
# 				var position = $(window).scrollTop();
# 				$(window).scroll(function(event){
# 					var scroll = $(window).scrollTop();
# 					if(scroll > position+30) {
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					} else {
# 						// 向下滑动内容
# 						if((scroll < position-30) && openTopBarId == false) {
# 							openTopBarId = true;
# 							$('.chapter-header').stop().css('top','0px');
# 						}
# 					}
# 					position = scroll;
# 				});
# 			}
# 			// 全屏
# ...
# 			}
# 			platform();
# 		</script>
# 	</body>
# </html>
# 第04话
# https://www.m298.com/798comic_269544/789749.html
# <!doctype html>
# <html>
# 	<head>
# 		<meta charset="gbk" />
# 		<title>无职转生洛琪希也要拿出真本事漫画“第04话”在线免费观看下拉式阅读，漫迷二九八</title>
# 		<meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 		<meta name="keywords" content="无职转生洛琪希也要拿出真本事漫画,无职转生洛琪希也要拿出真本事漫画在线,无职转生洛琪希也要拿出真本事漫画免费,无职转生洛琪希也要拿出真本事漫画免费阅读,无职转生洛琪希也要拿出真本事漫画在线观看,无职转生洛琪希也要拿出真本事漫画下拉式" />
# 		<meta name="description" content="无职转生洛琪希也要拿出真本事漫画“第04话”在线免费观看下拉式阅读，漫画剧情：描述小说无职转生到了异世界就拿出真本事中人气角色洛琪希的人生的外传漫画。 发觉自己从出生时就没有一族" />
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 		<link rel="shortcut icon" type="image/x-icon" href="https://www.m298.com/favicon.ico" media="screen" />
# 		<!-- <link href="/static/css/style.css" type="text/css" rel="stylesheet"> -->
#
# 		<link href="/static/css/base.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link href="/static/css/main.css?v=1.0.5" type="text/css" rel="stylesheet">
# 		<link rel="stylesheet" href="/static/font/iconfont.css">
#
# 		<!-- <link rel="stylesheet" href="/static/css/font-awesome.min.css"> -->
# 		<!--[if IE 7]><link rel="stylesheet" href="//cdn.bootcss.com/font-awesome/3.2.1/css/font-awesome-ie7.min.css"><![endif]-->
# 		<script type="text/javascript" src="https://apps.bdimg.com/libs/jquery/1.7.2/jquery.min.js"></script>
# 		<script type="text/javascript" src="/static/js/common.js?v=1.0.5"></script>
# 		<!-- <script type="text/javascript" src="/static/js/jquery.lazyload.js"></script> -->
# 		<script type="text/javascript" src="/static/js/yuedu.js?v=1.0.5"></script>
# 	</head>
# 	<body class="chapter-page">
# 		<div class="chapter-header">
# 			<div class="header-logo"><a href="/"><img src="/static/images/logo.png" alt="logo"></a></div>
# 			<div class="header-full"><a id="js_full_screen" href="javascript:void(0);">全屏</a></div>
# 			<div class="header-center line-clamp-1">
# 				<a href="/">首页</a> > <a href="/798comic_269544/">无职转生洛琪希也要拿出真本事</a> > <span>第04话</span>
# 			</div>
# 		</div>
# 		<div class="chapter-tool-box">
# 			<!-- <div class="tool-item">
# 				<span class="iconfont icon-shoucang_2"></span>
# 				<span>收藏</span>
# 			</div> -->
# 			<div class="tool-item" id="open_lights">
# 				<span class="iconfont icon-kaideng"></span>
# 				<span>关灯</span>
# 			</div>
# 			<div class="tool-item" id="open_chapter">
# 				<span class="iconfont icon-mulu"></span>
# 				<span>章节</span>
# 			</div>
# 			<div class="tool-tag"></div>
#
# 			<a  href="https://www.m298.com/798comic_269544/789748.html" class="tool-item">
#
# 				<span class="iconfont icon-shangyihua"></span>
# 				<span>上一话</span>
# 			</a>
#
# 			<a href="https://www.m298.com/798comic_269544/789744.html" class="tool-item">
#
# 				<span class="iconfont icon-xiayihua"></span>
# 				<span>下一话</span>
# 			</a>
# 		</div>
# 		<div class="arrow-ri none">
# 			<div class="arrow-ri-s"></div>
# 		</div>
# 		<div class="chapter-list none">
# 			<h2 class="line-clamp-1">《无职转生洛琪希也要拿出真本事》目录</h2>
# 			<div class="chapter-list-scroll">
# 				<ul id="789749">
#
# 				</ul>
# 			</div>
# 		</div>
# 		<div class="article-content-box container clearfix mt20">
# 			<div class="chapter-content" >
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/1_44f6de.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/2_b239d0.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/3_bedbf2.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/4_144ae4.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/5_150523.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/6_0b73b8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/7_5b2d68.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/8_f4217f.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/9_d0da4a.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/10_1e11dc.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/11_7bcf81.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/12_c3c56f.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/13_27c5ab.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/14_eda704.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/15_e12a88.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/16_f2c765.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/17_af15fd.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/18_39ffee.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/19_8b3b16.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/20_5b76f9.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/21_f2b4b8.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/22_10b977.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/23_e31140.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/24_3f1cdd.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/25_182c61.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/26_996041.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/27_496449.jpg" alt="" style="display: inline-block;">
#
# 				<img class="lazy-img" data-original="https://img.testrainshine.top/prod/52/52134/1731611/28_2fd791.jpg" alt="" style="display: inline-block;">
#
# 			</div>
# 			<div class="class-block-box clearfix" style="float:left;width:100%;">
# 				<div class="class-head" >
# 					<span>精品</span><span class="select-color">推荐</span>
# 				</div>
# 				<ul class="cartoon-block-box clearfix" >
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_288124/">
# 								<img src="https://img.testrainshine.top/prod/71/71389/71389s.jpg" alt="伪恋"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">4seasons04</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_288124/" class="hover-a">伪恋</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_301185/">
# 								<img src="https://img.testrainshine.top/prod/84/84503/84503s.jpg" alt="寄生兽"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第8卷 完全版</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_301185/" class="hover-a">寄生兽</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_221682/">
# 								<img src="https://img.testrainshine.top/prod/2/2829/2829s.jpg" alt="阿兹漫画大王"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">重复隐藏</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_221682/" class="hover-a">阿兹漫画大王</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_268110/">
# 								<img src="https://img.testrainshine.top/prod/50/50639/50639s.jpg" alt="游人贤者"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第03话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_268110/" class="hover-a">游人贤者</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_269548/">
# 								<img src="https://img.testrainshine.top/prod/52/52138/52138s.jpg" alt="JK是电车痴汉"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">短篇</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_269548/" class="hover-a">JK是电车痴汉</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_287761/">
# 								<img src="https://img.testrainshine.top/prod/71/71026/71026s.jpg" alt="王者天下"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第830话</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_287761/" class="hover-a">王者天下</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 					<li>
# 						<div class="cart-item">
# 							<a class="cart-cover" href="https://www.m298.com/798comic_288332/">
# 								<img src="https://img.testrainshine.top/prod/71/71597/71597s.jpg" alt="校花的贴身高手"  onerror="this.src='/modules/article/images/nocover.jpg';this.onerror=null;">
# 								<span class="new-chapter line-clamp-1">第14话 杀气</span>
# 							</a>
# 							<div class="cart-info">
# 								<p class="line-clamp-1"><a href="https://www.m298.com/798comic_288332/" class="hover-a">校花的贴身高手</a></p>
# 								<span class="line-clamp-1"></span>
# 							</div>
# 						</div>
# 					</li>
#
# 				</ul>
# 			</div>
# 		</div>
# 		<script>
# 			$(function(){
# 				openTopBarId = false;
# 				// 开灯的设置
# 				open_lights = 0;
# 				kaideng();
# 				// 设置顶部状态栏的显隐
# 				showHideTop();
# 				// $(".lazy-img").lazyload();
# 				setChapterList();
# 				$('#js_full_screen').click(function(de){
# 					changeFullScreen();
# 				})
# 			});
# 			// 获取章节列表
# 			chapterPageGetList('269544');
# 			// 记录阅读记录
#             history_save({
# 				articleid:'269544',
# 				articlename:'无职转生洛琪希也要拿出真本事',
# 				articlelink:'/798comic_269544/',
# 				cover_image:'https://img.testrainshine.top/prod/52/52134/52134s.jpg',
# 				chapterlink_read:'/798comic_269544/789749.html',
# 				chapterid_read:'789749',
# 				chaptername_read:'第04话',
# 				author:'石见翔子'});
# 			function setChapterList(){
# 				$('body').click(function(){
# 					$('.chapter-list').addClass('none');
# 					$('.arrow-ri').addClass('none');
# 					if(!openTopBarId){
# 						$('.chapter-header').stop().css('top','0px');
# 						openTopBarId = true;
# 					}else{
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					}
# 				})
# 				$('.chapter-list').click(function(e){
# 					e.stopPropagation();
# 				})
# 				$('#open_chapter').click(function(e){
# 					e.stopPropagation();
# 					if($('.chapter-list').attr('class').indexOf('none')>=0){
# 						// 展示章节
# 						$('.chapter-list').removeClass('none');
# 						$('.arrow-ri').removeClass('none');
# 					}else{
# 						$('.chapter-list').addClass('none');
# 						$('.arrow-ri').addClass('none');
# 					}
# 				})
# 			}
# 			// 设置开关灯
# 			function kaideng(){
# 				$('#open_lights').click(function(e){
# 					e.stopPropagation();
# 					if(tool_kaideng == 1){
# 						Cookie.set("tool_kaideng",0);
# 						tool_kaideng = 0;
# 						$('.chapter-page').removeClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('关灯');
# 					}else{
# 						Cookie.set("tool_kaideng",1);
# 						tool_kaideng = 1;
# 						$('.chapter-page').addClass('chapter-douse');
# 						$('#open_lights').children('span').eq(1).html('开灯');
# 					}
# 				});
# 				tool_kaideng = Cookie.get("tool_kaideng")?Cookie.get("tool_kaideng"):0;
# 				if(tool_kaideng == 1){
# 					// 关灯
# 					$('.chapter-page').addClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('开灯');
# 				}else{
# 					// 默认开灯
# 					$('.chapter-page').removeClass('chapter-douse');
# 					$('#open_lights').children('span').eq(1).html('关灯');
# 				}
# 			}
# 			// 设置顶部状态栏的显隐
# 			function showHideTop(){
# 				var position = $(window).scrollTop();
# 				$(window).scroll(function(event){
# 					var scroll = $(window).scrollTop();
# 					if(scroll > position+30) {
# 						$('.chapter-header').stop().animate({top:"-50px"},'fast','linear');
# 						openTopBarId = false;
# 					} else {
# 						// 向下滑动内容
# 						if((scroll < position-30) && openTopBarId == false) {
# 							openTopBarId = true;
# 							$('.chapter-header').stop().css('top','0px');
# 						}
# 					}
# 					position = scroll;
# 				});
# 			}
# 			// 全屏
# 			function changeFullScreen() {
#         		document.fullscreenElement || document.mozFullScreenElement || document.webkitFullscreenElement || document.msFullscreenElement ? document.exitFullscreen ? document.exitFullscreen() : document.msExitFullscreen ? document.msExitFullscreen() : document.mozCancelFullScreen ? document.mozCancelFullScreen() : document.webkitExitFullscreen && document.webkitExitFullscreen() : document.documentElement.requestFullscreen ? document.documentElement.requestFullscreen() : document.documentElement.msRequestFullscreen ? document.documentElement.msRequestFullscreen() : document.documentElement.mozRequestFullScreen ? document.documentElement.mozRequestFullScreen() : document.documentElement.webkitRequestFullscreen && document.documentElement.webkitRequestFullscreen(Element.ALLOW_KEYBOARD_INPUT)
# 			}
# 			platform();
# 		</script>
# 	</body>
# </html>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 42
#      39 response.encoding = 'gbk'
#      40 print(response.text)
# ---> 42 time.sleep(1)
#
# KeyboardInterrupt:
